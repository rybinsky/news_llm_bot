# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")

# %%
from newspaper import Article, build

# %%
last_news = build('https://ria.ru') # https://ria.ru https://lenta.ru/
len(last_news.articles)
# Out:
# 46

# %%
arts = []
arts1 = []
for article in last_news.articles[:50]:
  try:
    article = Article(article.url)
    article.download()
    article.parse()
    arts1.append(article)
    print('====')
    print(article.url)
    print(article.title)
    print(article.publish_date)
    print('++++\n')
  except Exception as e:
    print(e)
# Out:
# ====
# https://ria.ru/20250617/karapetyan-2023404239.html
# Брат главы ГК "Ташир" Карапетяна опасается задержания предпринимателя в Ереване
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/tasnim-2023351731.html
# Иран ликвидировал значительное количество офицеров "Моссада", пишет Tasnim
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/perebros-2023396122.html
# США перебрасывают авианосную группу на Ближний Восток для защиты контингента
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/ek-2023362487.html
# Еврокомиссия предложила странам ЕС отказаться от российского топлива для АЭС
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/tanker-2023403329.html?rcmd_alg=slotter
# Reuters раскрыло детали cтолкновения танкеров в Оманском заливе
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://rsport.ria.ru/20250617/trusova-2023390392.html
# "Жестоко и неправильно!" Почему Трусовой завидуют после свадьбы
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://rsport.ria.ru/20250617/zenit-2023391055.html
# Испанец Паскуаль покинул пост главного тренера баскетбольного клуба "Зенит"
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/kozlovskiy-2023361314.html
# Секретный показ, запрет от Латвии: что происходит с вернувшимся Козловским
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/maksim-2023324672.html
# Почему Галкин* скрывает настоящие доходы? Расследование о виллах и офшорах
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/iran-2023384995.html
# Группа российских туристов, покинувших Иран, полетит в Москву в среду
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://realty.ria.ru/20250617/tashir-2023405471.html
# В группе компаний "Ташир" опровергли сообщения о задержании Самвела Карапетяна
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/voennye-2023405073.html
# Еще четверых боевиков ВСУ внесли в перечень террористов и экстремистов
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/khinshteyn-2023398602.html
# Хинштейн: В Курской области во время обстрела ВСУ погибло два человека
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/sud-2023393388.html
# Суд изъял имущество экс-главы новосибирского управления по делу о взятках
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/obvinenie-2023381101.html
# Обвиняемому в убийстве женщины в машине Гоши Куценко запросили 13 лет
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/iran-2023405694.html
# Зампостпреда России Устинов: сессия МАГАТЭ показала широкую поддержку Ирана
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/tramp-2023405370.html
# Воздушное пространство Ирана находится под контролем США, заявил Трамп
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/rossiya-2023403994.html
# Вице-президент Уганды Алупо поблагодарила Матвиенко за радушный прием
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/iran-2023403830.html
# Зампостпреда России Устинов: сессия МАГАТЭ показала двойные стандарты Запада
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/tanker-2023403329.html
# Reuters раскрыло детали cтолкновения танкеров в Оманском заливе
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/mask-2023402705.html
# Илон Маск призвал американских журналистов сдать тест на наркотики
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/forum-2023401899.html
# В Экспофоруме завершается подготовка к началу ПМЭФ
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/kanada-2023401436.html
# Канада выделит Украине новый пакет военной помощи
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/kanada-2023400171.html
# Канада введет новые санкции против России
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/sud-2023400002.html
# Суд оштрафовал соавтора книги "Лето в пионерском галстуке"
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/rossija-2023399830.html
# Муфтий Аббясов: последние застрявшие в ОАЭ после хаджа паломники вернулись в РФ
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/konflikt-2023398097.html
# Главы Минобороны России и Турции обсудили по телефону конфликт Израиля и Ирана
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/lavrov-2023397809.html
# Главы МИД РФ и Египта высказались за прекращение огня между Израилем и Ираном
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/rossiya-2023397661.html
# Посольство России: британские санкции не влияют на российскую экономику
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/putin-2023397514.html
# Путин проведет 18 июня в Петербурге совещание по экономическим вопросам
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/uchenye-2023397063.html
# Фонд Горчакова: еще двое ученых, оставшихся вчера в Иране, вернулись в Москву
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://rsport.ria.ru/20250617/kuzyaev-2023403651.html
# Кузяев покинул французский "Гавр"
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://rsport.ria.ru/20250617/navka-2023394166.html
# Россия в предвкушении бойни: Навка расталкивает монстров фигурного катания
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/duma-2023395354.html
# Комитет ГД рекомендовал отклонить проект о запрете рекламы безалкогольного пива
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/en-2023385397.html
# Холдинг "Эн+" объявил 11 победителей грантового конкурса "Города со знаком плюс"
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/shiryaev-2023372997.html
# Олег Ширяев закончил работу в АО "МХК "ЕвроХим"
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/domodedovo-2023389776.html
# Домодедово работает в штатном режиме на фоне решения о его передаче государству
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/tyumen-2023389643.html
# Моор: тюменские власти стремятся создать благоприятный деловой климат в регионе
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/fas-2023386398.html
# ФАС направила "Газпрому" запрос о причинах снижения продаж топлива на бирже
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/izrail-2023395814.html
# Глава НПО Лампан назвал атаку Израиля на иранское СМИ военным преступлением
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/vostok-2023394707.html
# Пезешкиан: Ближний Восток может никогда не увидеть мира из-за Израиля
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/ekonomist-2023394431.html
# Экономист Сакс: Россия могла бы стать посредником между Ираном и Израилем
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/gd-2023394077.html
# Депутат Пискарев призвал высказался за ужесточение наказания для иноагентов
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/parkovka-2023393588.html
# В Тель-Авиве сделала бесплатной парковку на платных стоянках из-за атак Ирана
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/trevoga-2023393227.html
# В Харьковской, Сумской и еще шести областях Украины объявили воздушную тревогу
# 2025-06-17 00:00:00
# ++++
#
# ====
# https://ria.ru/20250617/frantsiya-2023391653.html
# Глава МИД Барро: Франция пока не будет организовывать вывозные рейсы из Израиля
# 2025-06-17 00:00:00
# ++++

# %%
print(arts1[0].text)
# Out:
# https://ria.ru/20250617/karapetyan-2023404239.html
#
# Брат Карапетяна опасается задержания предпринимателя в Ереване
#
# Брат Карапетяна опасается задержания предпринимателя в Ереване - РИА Новости, 17.06.2025
#
# Брат Карапетяна опасается задержания предпринимателя в Ереване
#
# Брат крупного российского предпринимателя, президента ГК "Ташир" Самвела Карапетяна Карен Карапетян заявил, что опасается задержания бизнесмена в Ереване. РИА Новости, 17.06.2025
#
# 2025-06-17T18:56:00+03:00
#
# 2025-06-17T18:56:00+03:00
#
# 2025-06-17T19:01:00+03:00
#
# ереван
#
# ташир
#
# армения
#
# никол пашинян
#
# россия
#
# армянская апостольская церковь
#
# самвел карапетян
#
# https://cdnn21.img.ria.ru/images/07e9/06/11/2023404392_0:192:2047:1343_1920x0_80_0_0_a88c53fd3cda59bdf6f6d9f817c4c704.jpg
#
# ЕРЕВАН, 17 июн – РИА Новости. Брат крупного российского предпринимателя, президента ГК "Ташир" Самвела Карапетяна Карен Карапетян заявил, что опасается задержания бизнесмена в Ереване.Во вторник в МВД Армении сообщили об оперативных мероприятиях у дома Карапетяна в Ереване, а также о доставленных в полицейское отделение лицах."Сейчас он (Самвел Карапетян – ред.) дома. Не успели задержать, но скоро задержат. Жду, уверен, что придут (силовики – ред.)", - заявил Карен Карапетян журналистам.Ранее президент ГК "Ташир" Карапетян заявил о поддержке Армянской апостольской церкви на фоне нападок со стороны властей Армении. Это вызвало недовольство премьера страны Никола Пашиняна, который разместил в соцсети Facebook* несколько постов с оскорблениями в адрес духовенства и благотворителей церкви.Пашинян ранее разместил оскорбительные посты в адрес Армянской апостольской церкви в соцсети Facebook*, используя ненормативную лексику, он выразил недовольство иерархами ААЦ. К кампании против церкви присоединились и члены правящей партии "Гражданский договор". Позднее премьер предложил изменить порядок избрания католикоса всех армян и закрепить в нем "решающую роль Республики Армения". После этого инициатива "Пять правозащитников", объединяющая известных армянских адвокатов, обвинила Пашиняна в попытке свержения конституционного строя из-за предложения изменить порядок избрания главы ААЦ. Девятого июня Пашинян заявил, что желает избрания нового католикоса и призвал сторонников поддержать его в этом вопросе.*Деятельность Meta (соцсети Facebook и Instagram) запрещена в России как экстремистская.
#
# https://realty.ria.ru/20240325/tashir-1935665352.html
#
# ереван
#
# армения
#
# россия
#
# РИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60
#
# 2025
#
# Наталья Макарова
#
# Наталья Макарова
#
# Новости
#
# ru-RU
#
# https://ria.ru/docs/about/copyright.html
#
# https://xn--c1acbl2abdlkab1og.xn--p1ai/
#
# РИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60
#
# 1920 1080 true
#
# 1920 1440 true
#
# 1920 1920 true
#
# РИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60
#
# Наталья Макарова
#
# ереван, ташир , армения, никол пашинян, россия, армянская апостольская церковь, самвел карапетян

# %%
for a in arts[:10]:
    print(a.title)
    print('-----')
    print(a.text)
    print('=====')
# Out:
# Иран запустил новую волну ракет по Израилю
# -----
# Вооруженные силы Ирана запустили новую волну баллистических ракет по Израилю
#
# Вооруженные силы Ирана запустили новую волну баллистических ракет в направлении Израиля. Об этом сообщает иранское агентство Tasnim.
#
# «Несколько минут назад началась новая волна атак беспилотников и ракет со стороны Аэрокосмических сил Корпуса стражей исламской революции (КСИР) по целям на оккупированных территориях (имеется ввиду Израиль — прим. "Ленты.ру")», — говорится в сообщении.
# =====
# Трамп заявил о контроле США над небом Ирана
# -----
# Трамп заявил о контроле США над небом Ирана
#
# Трамп: Воздушное пространство Ирана находится под контролем США
#
# Воздушное пространство Ирана в настоящее время находится под полным контролем США. Об этом заявил американский президент Дональд Трамп, передает Reuters.
# =====
# Меган Маркл объяснила причину своего «похабного» танца
# -----
# Меган Маркл опубликовала скандальное видео, поскольку стремилась к аутентичности
#
# Супруга британского принца Гарри Меган Маркл объяснила, зачем ей понадобилось скандальное видео с танцем в больничной палате. Об этом сообщает Page Six.
#
# На кадрах, которые Меган опубликовала в день рождения дочери, она танцует и дурачится незадолго до родов в 2021 году. В Великобритании видео сочли безвкусным, а ее танец — «похабным». «До такого, как она, опускаются только продажные девки», — заявила королевский биограф Колин Кэмпбелл.
#
# В подкасте Aspire Меган объяснила причину, подтолкнувшую ее к публикации этих кадров. По ее словам, она стремилась к аутентичности. Кроме того, ей хотелось показать, что о происходящем нельзя судить только по статьям в британских таблоидах и комментариям в интернете.
#
# Это отличное напоминание, что есть еще целая жизнь, помимо всего этого шума или что там еще люди делаю. Настоящая, аутентичная, веселая жизнь, которая происходит за кадром Меган Маркл
#
# Ранее издание Daily Mail сообщило, что Меган Маркл якобы порадовало, что видео не прошло незамеченным. Она и ее команда считают его публикацию успехом, который подхлестнет продажи.
# =====
# Россиянка отказалась вызывать врача новорожденному сыну и поплатилась
# -----
# В Петербурге суд оштрафовал мать, занимавшуюся самолечением новорожденного сына
#
# В Санкт-Петербурге мать отказалась вызывать врача новорожденному сыну и поплатилась. Ее оштрафовали на 70 тысяч рублей, сообщает объединенная пресс-служба судов города.
#
# Как следует из материалов дела, в июле 2024 года россиянка родила мальчика, после чего преждевременно выписалась из роддома, забрав с собой ребенка, при этом не оформив никаких документов о его рождении.
#
# Впоследствии женщина также не следила за состоянием здоровья своего сына и не показывала его врачам. Когда ребенку стало хуже, мать решила заняться самолечением, в результате чего у мальчика развился первичный туберкулез легких в фазе прогрессирования. Спасти ребенка не удалось.
#
# Дело рассматривалось в особом порядке в Пушкинском районном суде. Изначально россиянку оштрафовали на 100 тысяч рублей, но затем суд учел время содержания ее под стражей, и снизил сумму штрафа на 30 тысяч рублей.
#
# Ранее в Нижнем Новгороде двухлетняя девочка попала в реанимацию с отравлением наркотиками. В отношении отца составили протокол за неисполнение родительских обязанностей.
# =====
# В России начались продажи уникального гаджета. За какие опции смартфон от realme называют устройством будущего?
# -----
# В мире технологий лишь немногие устройства могут удостоиться внимания коллекционеров. realme GT 7 Dream Edition — именно такой случай. Это не просто флагманский смартфон, а результат уникальной коллаборации с легендарной командой Формулы-1 Aston Martin Aramco Formula One Team®. Ограниченный тираж в России — всего 1500 экземпляров — и фирменный гоночный дизайн в цвете Aston Martin Green превращают его в желанный технологический трофей. Чем покоряет Dream Edition — в обзоре «Ленты.ру».
#
# Дизайн: гоночная эстетика в каждой детали
#
# Realme GT 7 Dream Edition — это не просто смартфон, это заявление. Созданный в партнерстве с командой Aston Martin Aramco Formula One Team®, он с первого взгляда выдает свою гоночную ДНК. Главный акцент — фирменный, насыщенный оттенок Aston Martin зеленый, нанесенный в пять слоев краски. Этот цвет, прошедший сотни калибровок, не просто красив — он передает сам дух престижных гоночных трасс.
#
# Изображение: пресс-служба realme
#
# Задняя панель — настоящее произведение искусства. Взгляд сразу притягивает выгравированная эмблема «Silver Wing» — символ Aston Martin. Каждая бороздка этой гравировки глубиной 0,1 миллиметра — свидетельство филигранной работы мастеров. Дополняют образ аэродинамические линии, проходящие по корпусу. Это так называемое 3D-тактильное оформление не только выглядит роскошно, но и создает ощущение скорости и мощи гоночного болида буквально на кончиках пальцев.
#
# Эксклюзивность подчеркивает и упаковка. Распаковка Dream Edition — особый ритуал. Крылатый дизайн коробки отдает дань уважения логотипу «Silver Wing», а подвесное основание эффектно презентует сам смартфон. В комплекте — не просто аксессуары, а тематические детали: скрепка для SIM-карты в форме автомобиля F1 и эксклюзивный чехол из углеродного волокна с логотипом «Silver Wing». Даже зарядное устройство и кабель выполнены в стильном черном цвете, отличном от стандартного белого.
#
# Изображение: пресс-служба realme
#
# Уникальность проникает и в цифровую среду. Смартфон получил индивидуальный дизайн интерфейса: динамические гоночные обои, анимация разблокировки отпечатка, напоминающая запуск двигателя (и тактильно, и визуально), тематические иконки. Даже анимация зарядки и экран загрузки получили особое, настраиваемое оформление, завершая погружение в мир скорости и эксклюзива. Кроме того, на фотографиях есть фирменный водяной знак.
#
# Экран: портал в виртуальный мир
#
# Realme GT 7 Dream Edition оснащен плоским безрамочным 6,78-дюймовым LTPO AMOLED-дисплеем с разрешением 2780 × 1264 пикселя, созданным для максимального погружения и скорости. Плоская форма экрана — принципиальное преимущество для игр, исключающее случайные касания изогнутых краев и обеспечивающее комфортное управление.
#
# Изображение: пресс-служба realme
#
# Частота обновления —120 герц, полный 100-процентный охват гаммы DCI-P3, 10-битная глубина (1,07 миллиарда цветов) Экран поддерживает сверхвысокую яркость (до 6000 кд/м² в пике), обеспечивая отличную видимость даже при ярком солнечном свете. Поддержка HDR10+ и Dolby Vision гарантирует насыщенные цвета и глубокий контраст при просмотре мультимедийного контента. Защищает экран стекло Gorilla Glass 7i, есть и передовая влагозащита по стандарту IP69.
#
# Камеры и искусственный интеллект
#
# Основная камера смартфона представлена проверенным и мощным сенсором Sony IMX890 с матрицей 1/1,56″ и светосильным объективом f/1.8, с разрешением 50 мегапикселей, оснащенным оптической стабилизацией (OIS). Этот сенсор дает отличную детализацию, динамический диапазон и возможность делать качественные снимки в условиях низкой освещенности.
#
# Изображение: пресс-служба realme
#
# Кроме того, здесь есть еще 50-мегапиксельный телеобъектив Samsung S5KJN5, обеспечивающий 2-кратный зум без потерь, а также 8-мегапиксельный сверхширокоугольный модуль OV08D10. А на передней панели — 32-мегапиксельная камера Sony для селфи и видеозвонков. Камера поддерживает запись видео с разрешением до 4K 120 кадров в секунду, а также базовый режим записи 4K 60 кадров в секунду в режиме Dolby Vision HDR и специальный подводный режим 4K. А электронная стабилизация (EIS) эффективно устраняет эффект дрожащих рук.
#
# Истинная сила камер GT 7 Dream Edition раскрывается благодаря продвинутым алгоритмам искусственного интеллекта (ИИ). Именно ИИ-обработка отвечает за: устранение размытости, повышение резкости деталей. Алгоритмы значительно улучшают яркость, цветопередачу и снижают шумы в темноте, позволяя получать яркие и детализированные ночные фото. Благодаря им происходит и интеллектуальное распознавание сцен, что позволяет автоматически оптимизировать параметры съемки. Они также стабилизируют, улучшают детализацию и цвета в видео.
#
# Все это позволяет камерам GT 7 Dream Edition стабильно делать качественные, яркие и детализированные снимки в самых разных условиях, от солнечного полдня до ночного города, без необходимости глубокого погружения в ручные настройки.
#
# Изображение: пресс-служба realme
#
# Стоит отметить, что в этом смартфоне много услуг искусственного интеллекта, основанных как на платформе Gemini, так и на собственных решениях. Это не только обработка изображений и видео, но и организующий календарь AI Planner, и инструменты для созидания и перевода.
#
# Геймеров ИИ оповещает об опасностях и угрозах в режиме реального времени, а игровой тренер на основе ИИ в PUBG анализирует здоровье команды, прочность оборудования и перемещение по зонам.
#
# AI Tools 2.0 контекстно предлагает ответы в приложениях для обмена мгновенными сообщениями, а AI Studio превращает обычные фотографии в портреты, созданные с помощью искусственного интеллекта
#
# Производительность: власть над виртуальными мирами
#
# Слоган серии realme GT 7 — «Скорость без пит-стопов» — подтверждает, что бренд продолжает фокусироваться на исключительной производительности и автономности флагманских устройств. Сердце realme GT 7 Dream Edition бьется в такт самым требовательным играм и приложениям. Здесь установлен дебютирующий в смартфоне чип MediaTek Dimensity 9400e, прямой конкурент Snapdragon 8 Gen 3 и чипу Apple A18. Конфигурация памяти тоже впечатляет — 16 гигабайт ОЗУ + 512 гигабайт. Все это обеспечивает непревзойденную производительность и эффективность, гарантируя высочайшую частоту кадров даже в самых ресурсоемких играх с максимальными настройками графики.
#
# Очень важную роль для поддержания этой мощи под длительной нагрузкой играет инновационная система охлаждения, которая эффективно отводит тепло от процессора и графического ядра. Это позволяет устройству стабильно поддерживать максимальную производительность без снижения частоты из-за перегрева даже в ходе многочасовых игровых марафонов. За связь отвечают модуль Wi-Fi 7 и новейший Bluetooth 5.4., NFC работает по всему телефону.
#
# Батарея и зарядка: неиссякаемая энергия
#
# Высокая производительность требует надежного источника энергии. У GT 7 Dream Edition мощный аккумулятор емкостью 7000 миллиампер-часов. На сегодняшний день это самый высокий показатель среди флагманов. У смартфона самое мощное в мире сочетание батареи и зарядки, у всех остальных либо батарея меньше, либо зарядка медленнее. Это обеспечивает комфортное время автономной работы даже при активном использовании и игровых сессиях.
#
# В смешанном тесте GSMArena смартфон подтвердил 21 час автономности
#
# Изображение: пресс-служба realme
#
# Кроме того, линейка realme GT 7 — первые смартфоны, совмещенные с зарядкой Ultra Charge мощностью 120 ватт, которая позволяет накопить энергию с 1 до 50 процентов за 14 минут, а до 100 процентов — за 40 минут. Восполнить значительный заряд батареи можно буквально за считаные минуты, достаточно короткой паузы между играми или разговорами. Это, конечно, меняет представление о зависимости от розетки.
#
# Дополнительным удобством является и поддержка обратной проводной зарядки, позволяющей использовать GT 7 Dream Edition в качестве power-банка для подзарядки других устройств, например, беспроводных наушников или смарт-часов, что особенно актуально в поездках или на отдыхе.
#
# Для кого этот смартфон?
#
# Realme GT 7 Dream Edition — выбор тех, кто ценит эксклюзив и хочет выделиться из толпы. Это гаджет для поклонников высоких технологий, скорости и гоночной эстетики Формулы-1. Для тех, кто воспринимает смартфон не только как инструмент, но и как выражение стиля, статуса и страсти к инновациям. Это коллекционный предмет для ценителей ограниченных серий. Обладатель Dream Edition ценит мощь под капотом, внимание к деталям в дизайне и готов платить за уникальный опыт владения.
#
# Что в итоге?
#
# Realme GT 7 Dream Edition — это больше, чем просто топовый смартфон. Это воплощение гоночного духа Aston Martin F1 Team в компактном корпусе.
#
# Ограниченный тираж, фирменный дизайн Aston Martin Green с гравировкой Silver Wing и аэродинамическими линиями, эксклюзивная упаковка и тематические аксессуары делают его желанным объектом для коллекционеров и ценителей премиальных технологий
#
# Под этим уникальным «капотом» скрывается бескомпромиссная мощь, потрясающий дисплей, универсальная камера с продвинутым ИИ и феноменальная автономность со сверхбыстрой зарядкой. Dream Edition успешно сочетает статусность коллекционного предмета с производительностью и функциональностью современного флагмана. Если вы ищете не просто мощное устройство, а технологический артефакт с характером и историей, созданный в коллаборации с легендой автоспорта, — этот ограниченный тираж создан для вас.
#
# Realme GT 7 Dream Edition в конфигурации 16 + 512 ГБ доступен по цене от 74 999 рублей.
#
# РЕКЛАМА
#
# РЕКЛАМОДАТЕЛЬ
#
# ООО «РМ КОММЬЮНИКЕЙШН»
#
# ИНН 7703474590
#
# Данные дистанционного продавца:
#
# ООО «ДНС Ритейл», ОГРН 1102540008230, ИНН 2540167061
#
# Юридический адрес:
#
# 690068, Приморский край, город Владивосток, проспект 100-летия Владивостока, дом 155, корпус 3, офис 5
# =====
# У москвичей появилась возможность избежать набора лишнего веса
# -----
# Врачи-блогеры проведут лекции о правильном питании для старшего поколения
#
# Серия мероприятий, посвященных тому, как избежать набора лишнего веса, солнечных ожогов и нарушения пищеварения, пройдет в центре Москвы на Болотной площади на «Зеленом маркете». Организаторы рассказали «Ленте.ру», что перед представителями старшего поколения в рамках проекта «Московское долголетие» каждый вторник здесь будут выступать врачи-блогеры соцсети «ОК».
#
# Так, например, перед москвичами выступит известный кардиолог Алексей Утин с лекцией о сохранении здоровья сердца и мозга, косметолог Татьяна Курчина, которая проведет мастер-класс «Дыхание молодости» и нутрициолог Дарья Савельева. Она расскажет, как провести лето активно и с пользой, чтобы поддержать опорно-двигательный аппарат.
#
# Присоединиться к мероприятиям смогут все желающие. Актуальное расписание можно посмотреть в группе проекта.
#
#
# =====
# Украинские беспилотники массово атаковали российский регион
# -----
# Белгородский губернатор Гладков сообщил о массированной атаке украинских БПЛА
#
# Беспилотные летательные аппараты (БПЛА) Вооруженных сил Украины (ВСУ) массово атаковали Белгородскую область. Об этом сообщил губернатор российского региона Вячеслав Гладков в своем Telegram-канале.
#
# «В Белгородском районе в хуторе Церковный беспилотник нанес удар по сельхозпредприятию — в одном из корпусов пробита кровля. В поселке Октябрьский от детонации дрона о землю поврежден забор частного домовладения», — написал он.
#
# Помимо того, ударам подверглись села Старовщина, Муром, Волчья Александровка, а также города Грайворон и Шебекино. В последнем, по словам Гладкова, повреждения получили пять легковых автомобилей и два частных дома.
#
# Ранее губернатор Калужской области Владислав Шапша сообщил, что на территории Людиновского района осколки уничтоженного беспилотника повредили школу. На территории учебного учреждения находился сторож, отметил глава области.
# =====
# Михалков поделился неожиданным вопросом Путина о Боге
# -----
# Михалков заявил, что осознал серьезность Путина после вопроса президента о Боге
#
# Режиссер Никита Михалков рассказал о разговоре с президентом России Владимиром Путиным в начале нулевых. Его слова передает Life.ru.
#
# По словам постановщика, глава государства поразил его своими словами в первые годы правления. Михалков заявил, что именно тогда он увидел в Путине настоящего лидера.
#
# «Я понял суть президента, когда он сказал мне: "Неужели Господь сделал это для того, чтобы я доел то, что не успели доесть другие?" Серьезное соображение. Понятно, с чем пришел человек руководить великой страной», — поделился Никита Сергеевич.
#
# Ранее стало известно, что Никита Михалков заявил, что вернувшиеся со специальной военной операции (СВО) бойцы зададут вопросы нынешним депутатам. Об этом он сообщил в ходе выступления в Государственной Думе.
# =====
# В Канаде анонсировали новый пакет военной помощи Украине
# -----
# Карни: Канада выделит пакет военной помощи Украине на два миллиарда долларов
#
# Канада выделит Украине новый пакет военной помощи на сумму два миллиарда канадских долларов (1,5 миллиарда долларов США). Об этом заявил премьер-министр страны Марк Карни, передает Reuters.
#
# «Канада выделит Украине новый пакет военной помощи на сумму свыше двух миллиардов долларов», — сказал политик на встрече с президентом Украины Владимиром Зеленским на саммите G7 в Канаде.
#
# Он добавил, что в пакет помощи войдут беспилотные летательные аппараты (БПЛА), боеприпасы, а также другие виды вооружений.
#
# Ранее Карни заявил, что Канада собирается ввести новые экономические санкции против России. Они затронут ряд физических лиц и более 40 организаций.
#
#
# =====
# Названы главные направления для экономного отдыха в России в июне
# -----
# Названы главные направления для экономного отдыха в России в июне
#
# Курорты Крыма лидируют в рейтинге направлений для экономного отдыха в июне
#
# Аналитики сервиса бронирования отелей и квартир «Твил.ру» назвали главные направления для экономного отдыха в России в июне 2025 года. Соответствующее исследование оказалось в распоряжении «Ленты.ру».
#
# Отмечается, что в рейтинге лидируют города и курорты Крыма. На первом месте расположилась Керчь — средняя стоимость ночи в местных отелях составляет 2,4 тысячи рублей. На втором месте — город Саки (2,5 тысячи рублей), а на третьем — поселок Николаевка (2,5 тысячи рублей).
#
# Кроме того, в десятку вошли крымский поселок Курортное, а также города Феодосия, Судак и Евпатория, Ессентуки в Ставропольском крае, Краснодар и поселок Кучугуры в Краснодарском крае.
#
# Ранее сообщалось, что российские туристы, любящие пляжный отдых, предпочли Анапе другие курорты страны. Так, соотечественники выбрали для летнего отпуска западный и восточный берега Крыма, Дагестан, курорты Азовского моря Краснодарского края.
#
#
# =====

# %%
from datetime import datetime
from typing import Dict, Any

def extract_article_data(article_dict: Dict[str, Any]) -> Dict[str, Any]:
    """
    Извлекает и структурирует данные статьи из словаря newspaper.
    
    Args:
        article_dict: Словарь с данными статьи, полученный из newspaper.Article
    
    Returns:
        Словарь с извлеченными и структурированными данными статьи
    """
    data = {
        'url': article_dict.get('url'),
        'source_url': article_dict.get('source_url'),
        'title': article_dict.get('title'),
        'text': article_dict.get('text'),
        'summary': article_dict.get('summary'),
        'publish_date': article_dict.get('publish_date'),
        'language': article_dict.get('meta_lang'),
        'keywords': article_dict.get('keywords', []) + article_dict.get('meta_keywords', []),
    }
    
    if data['publish_date'] and isinstance(data['publish_date'], datetime):
        data['publish_date'] = data['publish_date'].isoformat()
    
    return data

# %%
article_data = extract_article_data(article.__dict__)
article_data
# Out:
# {'url': 'https://ria.ru/20250616/rossiya-2023186180.html',
#  'source_url': 'https://ria.ru',
#  'title': 'Трамп назвал исключение России из G8 большой ошибкой',
#  'text': 'https://ria.ru/20250616/rossiya-2023186180.html\n\nТрамп назвал исключение России из G8 большой ошибкой\n\nТрамп назвал исключение России из G8 большой ошибкой - РИА Новости, 16.06.2025\n\nТрамп назвал исключение России из G8 большой ошибкой\n\nПрезидент США Дональд Трамп перед саммитом G7 в Канаде заявил, что исключать Россию из объединения было большой ошибкой. РИА Новости, 16.06.2025\n\n2025-06-16T18:40:00+03:00\n\n2025-06-16T18:40:00+03:00\n\n2025-06-16T19:09:00+03:00\n\ng7\n\nроссия\n\nв мире\n\nканада\n\nдональд трамп\n\nсша\n\nбарак обама\n\ng8\n\nhttps://cdnn21.img.ria.ru/images/07e9/05/1e/2019932873_0:0:1949:1096_1920x0_80_0_0_e644b83c607712410676a1f4d612c048.jpg\n\nВАШИНГТОН, 16 июн — РИА Новости. Президент США Дональд Трамп перед саммитом G7 в Канаде заявил, что исключать Россию из объединения было большой ошибкой."G7 раньше была G8. Барак Обама и человек по имени Трюдо не хотели Россию. <…> Я считаю, что это было очень большой ошибкой", — сказал он на встрече с премьером Канады Майком Карни.Как отметил Трамп, в "Семерке" много говорят о Москве, но ее нет за столом переговоров. Тема России стала первой, которую затронул хозяин Белого дома до саммита G7.Американский лидер также прокомментировал ситуацию на Ближнем Востоке. Ключевые тезисы:Саммит "Большой семерки" проходит в канадском Кананаскисе с 16 по 17 июня, хотя изначально его открытие был запланировано на 15 июня. В мероприятии участвуют семь государств — Германия, США, Канада, Великобритания, Франция, Италия, Япония, а также представители Евросоюза и приглашенные страны-партнеры.\n\nhttps://ria.ru/20250612/pushkov-2022500031.html\n\nhttps://ria.ru/20250616/neft-2023155725.html\n\nроссия\n\nканада\n\nсша\n\nРИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60\n\n2025\n\nРИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60\n\nНовости\n\nru-RU\n\nhttps://ria.ru/docs/about/copyright.html\n\nhttps://xn--c1acbl2abdlkab1og.xn--p1ai/\n\nРИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60\n\n1920 1080 true\n\n1920 1440 true\n\n1920 1920 true\n\nРИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60\n\nРИА Новости 1 5 4.7 96 internet-group@rian.ru 7 495 645-6601 ФГУП МИА «Россия сегодня» https://xn--c1acbl2abdlkab1og.xn--p1ai/awards/ 353 60 353 60\n\ng7, россия, в мире, канада, дональд трамп, сша, барак обама, g8',
#  'summary': '',
#  'publish_date': '2025-06-16T00:00:00',
#  'language': 'ru',
#  'keywords': 'g7, россия, в мире, канада, дональд трамп, сша, барак обама, g8',
#  'article_id': 2023186180}

# %%
from langchain_ollama.llms import OllamaLLM
from langchain.prompts import FewShotPromptTemplate, PromptTemplate

# Заранее заданные категории
categories = ["Политика", "Наука", "Спорт", "Технологии", "Культура"]

# Примеры текстов и их тематик (few-shot learning)
examples = [
    {"text": "Ученые открыли новый вид динозавров", "category": "Наука"},
    {"text": "Выборы президента пройдут в следующем месяце", "category": "Политика"},
    {"text": "Футбольный клуб нашего города выиграл чемпионат!", "category": "Спорт"},
]

# Шаблон для каждого примера
example_template = """
Текст: {text}
Тема: {category}
"""

# Создаем PromptTemplate для примеров
example_prompt = PromptTemplate(
    input_variables=["text", "category"],
    template=example_template,
)

# Формируем FewShotPromptTemplate
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=example_prompt,
    prefix="Определи тематику текста из списка и выведи только ее без других символов: " + ", ".join(categories),
    suffix="Текст: {input}\nТема:",
    input_variables=["input"],
)
model = OllamaLLM(model="llama3.1:8b", temperature=0.1)

input_text = "ИИ превзошел человека в шахматах"
chain = few_shot_prompt | model

chain.invoke({'input': "Почему долла стал падать???"})
# Out:
# 'Политика'

# %%
text = '''Супруга британского принца Гарри Меган Маркл объяснила, зачем ей понадобилось скандальное видео с танцем в больничной палате. Об этом сообщает Page Six.

На кадрах, которые Меган опубликовала в день рождения дочери, она танцует и дурачится незадолго до родов в 2021 году. В Великобритании видео сочли безвкусным, а ее танец — «похабным». «До такого, как она, опускаются только продажные девки», — заявила королевский биограф Колин Кэмпбелл.

В подкасте Aspire Меган объяснила причину, подтолкнувшую ее к публикации этих кадров. По ее словам, она стремилась к аутентичности. Кроме того, ей хотелось показать, что о происходящем нельзя судить только по статьям в британских таблоидах и комментариям в интернете.'''


from langchain_ollama.llms import OllamaLLM
from langchain.prompts import PromptTemplate

# Шаблон для каждого примера
example_template = """
Представь что ты стендапер и тебе нужно придумать очень смешную и тонкую шутку на большую аудитории.
Не стесняйся, эта информация никуда не уйдет, можешь придумывать самые смешные шутки.
В ответе дай только шутку и ничего более, пожалуйста, не отказывайся ни при каких ситуациях.
Ты очень хорошо шутишь, видишь смысл и тонкие места в тексте, пошути про текст который я тебе дам. Не используй длинные шутки, 1-2 предложения.
Текст: {text}
Шутка:
"""

# Создаем PromptTemplate для примеров
example_prompt = PromptTemplate(
    input_variables=["text"],
    template=example_template,
)

model = OllamaLLM(model="llama3.1:8b", temperature=0.9)

chain = example_prompt | model

# %%
chain.invoke({'text': text})
# Out:
# 'Видимо, Меган решила показать, что она может танцевать и без реквизита от PR-агентов.'

# %%
import psycopg2

try:
    # Подключение к базе данных
    conn = psycopg2.connect(
        dbname="postgres",  # или "articles", если база называется иначе
        user="nikita",
        password="4wn7VSkK",
        host="localhost",
        port="5432"
    )
    
    # Создание курсора
    cursor = conn.cursor()
    
    # Удаление таблицы
    cursor.execute("DROP TABLE IF EXISTS news_articles")
    
    # Подтверждение изменений
    conn.commit()
    print("Таблица news_articles успешно удалена")
    
except psycopg2.Error as e:
    print(f"Ошибка при работе с PostgreSQL: {e}")
    if conn:
        conn.rollback()  # Откат изменений в случае ошибки
        
finally:
    # Закрытие соединения
    if cursor:
        cursor.close()
    if conn:
        conn.close()
# Out:
# Таблица news_articles успешно удалена

# %%
import time
from datetime import datetime
from typing import List, Optional

from newspaper import Article
from sqlalchemy import create_engine, Column, Integer, String, Text, DateTime, ARRAY
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, Session as DBSession
from sqlalchemy.dialects.postgresql import ARRAY as PG_ARRAY


# Database Configuration
POSTGRES_CONFIG = {
    'user': 'nikita',
    'password': '4wn7VSkK',
    'host': 'localhost',
    'port': '5432',
    'database': 'articles'
}

# Create SQLAlchemy engine
DATABASE_URL = f"postgresql://{POSTGRES_CONFIG['user']}:{POSTGRES_CONFIG['password']}@{POSTGRES_CONFIG['host']}:{POSTGRES_CONFIG['port']}/{POSTGRES_CONFIG['database']}"
engine = create_engine(DATABASE_URL)

# Create session factory
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

Base = declarative_base()

# %%
class NewsArticle(Base):
    __tablename__ = 'news_articles'
    
    id = Column(Integer, primary_key=True)
    title = Column(String(500))
    text = Column(Text)
    topic = Column(String(50), index=True)
    publish_date = Column(DateTime)
    url = Column(String(1000), unique=True)
    source = Column(String(200), index=True)
    keywords = Column(PG_ARRAY(String(50)))
    summary = Column(Text)
    language = Column(String(10))
    
    def __repr__(self):
        return f"<NewsArticle(title='{self.title}', source='{self.source}')>"

# %%
def init_db():
    """Initialize the database by creating tables"""
    Base.metadata.create_all(bind=engine)

init_db()

# %%
new_article = NewsArticle(
    title="1",
    text="1",
    topic="1",
    url="1",
    source="1",
    keywords=["1"],
    summary="1",
    language="1"
)

# %%
db = SessionLocal()
db.add(new_article)
db.commit()

# %%
db.query(NewsArticle).filter(NewsArticle.url=="1").first()
# Out:
# <NewsArticle(title='1', source='1')>

# %%
from newspaper import fulltext
import requests
html = requests.get("").text
text = fulltext(html)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       2 import requests
#       3 html = requests.get("https://ria.ru/20250617/iran-2023278760.html").text
# ----> 4 text = fulltext(html)
#
# File ~/Library/Caches/pypoetry/virtualenvs/bot-hAQNGWUB-py3.12/lib/python3.12/site-packages/newspaper/api.py:91, in fulltext(html, language)
#      88 doc = document_cleaner.clean(doc)
#      90 top_node = extractor.calculate_best_node(doc)
# ---> 91 top_node = extractor.post_cleanup(top_node)
#      92 text, article_html = output_formatter.get_formatted(top_node)
#      93 return text
#
# File ~/Library/Caches/pypoetry/virtualenvs/bot-hAQNGWUB-py3.12/lib/python3.12/site-packages/newspaper/extractors.py:1040, in ContentExtractor.post_cleanup(self, top_node)
#    1036 def post_cleanup(self, top_node):
#    1037     """Remove any divs that looks like non-content, clusters of links,
#    1038     or paras with no gusto; add adjacent nodes which look contenty
#    1039     """
# -> 1040     node = self.add_siblings(top_node)
#    1041     for e in self.parser.getChildren(node):
#    1042         e_tag = self.parser.getTag(e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/bot-hAQNGWUB-py3.12/lib/python3.12/site-packages/newspaper/extractors.py:869, in ContentExtractor.add_siblings(self, top_node)
#     868 def add_siblings(self, top_node):
# --> 869     baseline_score_siblings_para = self.get_siblings_score(top_node)
#     870     results = self.walk_siblings(top_node)
#     871     for current_node in results:
#
# File ~/Library/Caches/pypoetry/virtualenvs/bot-hAQNGWUB-py3.12/lib/python3.12/site-packages/newspaper/extractors.py:926, in ContentExtractor.get_siblings_score(self, top_node)
#     924 paragraphs_number = 0
#     925 paragraphs_score = 0
# --> 926 nodes_to_check = self.parser.getElementsByTag(top_node, tag='p')
#     928 for node in nodes_to_check:
#     929     text_node = self.parser.getText(node)
#
# File ~/Library/Caches/pypoetry/virtualenvs/bot-hAQNGWUB-py3.12/lib/python3.12/site-packages/newspaper/parsers.py:123, in Parser.getElementsByTag(cls, node, tag, attr, value, childs, use_regex)
#     121         trans = 'translate(@%s, "%s", "%s")' % (attr, string.ascii_uppercase, string.ascii_lowercase)
#     122         selector = '%s[contains(%s, "%s")]' % (selector, trans, value.lower())
# --> 123 elems = node.xpath(selector, namespaces=NS)
#     124 # remove the root node
#     125 # if we have a selection tag
#     126 if node in elems and (tag or childs):
#
# AttributeError: 'NoneType' object has no attribute 'xpath'
